# %%
import pandas as pd
import numpy as np
import tensorflow
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib
# %matplotlib inline

# %%
(X_train,y_train),(X_test,y_test) = keras.datasets.fashion_mnist.load_data()

# %%
plt.figure(figsize=(14,4))
for i in range(0,10):
  plt.subplot(2,5,i+1)
  plt.imshow(X_train[i].reshape(28,28),cmap=None)

# %%
from keras.models import Sequential

# %%
batch_size = 512
num_class = 10
epochs = 30

# %%
X_train,X_test = X_train/255.0,X_test/255.0

# %%
model = Sequential()
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(batch_size,activation='relu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(num_class,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=epochs)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2270 - accuracy: 0.9136
# Epoch 2/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2213 - accuracy: 0.9166
# Epoch 3/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2177 - accuracy: 0.9167
# Epoch 4/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2134 - accuracy: 0.9201
# Epoch 5/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2091 - accuracy: 0.9209
# Epoch 6/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2039 - accuracy: 0.9228
# Epoch 7/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2018 - accuracy: 0.9234
# Epoch 8/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1976 - accuracy: 0.9251
# Epoch 9/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1935 - accuracy: 0.9269
# Epoch 10/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1913 - accuracy: 0.9270
# Epoch 11/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1905 - accuracy: 0.9281
# Epoch 12/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1843 - accuracy: 0.9304
# Epoch 13/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1814 - accuracy: 0.9308
# Epoch 14/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1793 - accuracy: 0.9316
# Epoch 15/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1766 - accuracy: 0.9325
# Epoch 16/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1753 - accuracy: 0.9327
# Epoch 17/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1709 - accuracy: 0.9352
# Epoch 18/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1683 - accuracy: 0.9353
# Epoch 19/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1676 - accuracy: 0.9357
# Epoch 20/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1644 - accuracy: 0.9378
# Epoch 21/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1628 - accuracy: 0.9378
# Epoch 22/30
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1580 - accuracy: 0.9401
# Epoch 23/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1596 - accuracy: 0.9388
# Epoch 24/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1569 - accuracy: 0.9396
# Epoch 25/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1572 - accuracy: 0.9392
# Epoch 26/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1531 - accuracy: 0.9418
# Epoch 27/30
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1523 - accuracy: 0.9409
# Epoch 28/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1504 - accuracy: 0.9424
# Epoch 29/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1457 - accuracy: 0.9435
# Epoch 30/30
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1455 - accuracy: 0.9450

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4095 - accuracy: 0.8975
# [0.409457266330719, 0.8974999785423279]
